# %% [markdown]
# Use Case Description:
#
# Predicting the diabetes disease
# Programming elements:
# Keras Basics
#
# In class programming:
# 1. Use the use case in the class:
# a. Add more Dense layers to the existing code and check how the accuracy changes.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation  # Updated import

# Load the diabetes dataset and convert it to a NumPy array
dataset = pd.read_csv("/content/diabetes.csv", header=None).values

# Split the dataset into input features (X) and the target variable (Y)
X_train, X_test, Y_train, Y_test = train_test_split(dataset[:, 0:8], dataset[:, 8], test_size=0.25, random_state=87)

# Set a random seed for reproducibility
np.random.seed(155)

# Create a Sequential model
my_first_nn = Sequential()

# Add a hidden layer with 20 neurons and ReLU activation function
my_first_nn.add(Dense(20, input_dim=8, activation='relu'))

# Add an output layer with a single neuron and a sigmoid activation function for binary classification
my_first_nn.add(Dense(1, activation='sigmoid'))

# Compile the model with binary cross-entropy loss and the Adam optimizer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fit (train) the model on the training data for 100 epochs
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, initial_epoch=0)

# Print a summary of the model architecture
print(my_first_nn.summary())

# Evaluate the model on the test data and print the loss and accuracy
loss, accuracy = my_first_nn.evaluate(X_test, Y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 2ms/step - loss: 7.6469 - accuracy: 0.6094
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 4.9948 - accuracy: 0.5955
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 3.0426 - accuracy: 0.5486
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 2.2776 - accuracy: 0.5243
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.9069 - accuracy: 0.5295
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.7224 - accuracy: 0.5642
# Epoch 7/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.5462 - accuracy: 0.5729
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.4519 - accuracy: 0.5712
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2791 - accuracy: 0.5799
# Epoch 10/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.1769 - accuracy: 0.5764
# Epoch 11/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0804 - accuracy: 0.6128
# Epoch 12/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0305 - accuracy: 0.6354
# Epoch 13/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0106 - accuracy: 0.5990
# Epoch 14/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9308 - accuracy: 0.6181
# Epoch 15/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.9286 - accuracy: 0.6389
# Epoch 16/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8516 - accuracy: 0.6632
# Epoch 17/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8402 - accuracy: 0.6597
# Epoch 18/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8162 - accuracy: 0.6510
# Epoch 19/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7993 - accuracy: 0.6667
# Epoch 20/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.8429 - accuracy: 0.6389
# Epoch 21/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7847 - accuracy: 0.6667
# Epoch 22/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7822 - accuracy: 0.6528
# Epoch 23/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7489 - accuracy: 0.6476
# Epoch 24/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7441 - accuracy: 0.6649
# Epoch 25/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7305 - accuracy: 0.6753
# Epoch 26/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7166 - accuracy: 0.6701
# Epoch 27/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7119 - accuracy: 0.6753
# Epoch 28/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7032 - accuracy: 0.6649
# Epoch 29/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6963 - accuracy: 0.6771
# Epoch 30/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6857 - accuracy: 0.6701
# Epoch 31/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6819 - accuracy: 0.6892
# Epoch 32/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7044 - accuracy: 0.6615
# Epoch 33/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6864 - accuracy: 0.6701
# Epoch 34/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6889 - accuracy: 0.6545
# Epoch 35/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6764 - accuracy: 0.6927
# Epoch 36/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6580 - accuracy: 0.6892
# Epoch 37/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6508 - accuracy: 0.6788
# Epoch 38/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6459 - accuracy: 0.6944
# Epoch 39/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6325 - accuracy: 0.6823
# Epoch 40/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6322 - accuracy: 0.7014
# Epoch 41/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6269 - accuracy: 0.6979
# Epoch 42/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6344 - accuracy: 0.6806
# Epoch 43/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6145 - accuracy: 0.7188
# Epoch 44/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6286 - accuracy: 0.6927
# Epoch 45/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6174 - accuracy: 0.6823
# Epoch 46/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6160 - accuracy: 0.7031
# Epoch 47/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6086 - accuracy: 0.6997
# Epoch 48/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6056 - accuracy: 0.6962
# Epoch 49/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6096 - accuracy: 0.7083
# Epoch 50/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6001 - accuracy: 0.7066
# Epoch 51/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.
model
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),  # Flatten the 28x28 input images
    tf.keras.layers.Dense(128, activation='relu'),  # Fully connected layer with ReLU activation
    tf.keras.layers.Dropout(0.2),  # Dropout layer to prevent overfitting
    tf.keras.layers.Dense(10)  # Output layer with 10 units for 10 classes (digits 0-9)
])

# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=10, validation_data=(x_val, y_val))

# Plot the loss and accuracy for both training and validation data
plt.figure(figsize=(12, 4))

# Plot training & validation loss values
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2959 - accuracy: 0.9143 - val_loss: 0.1321 - val_accuracy: 0.9613
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1425 - accuracy: 0.9572 - val_loss: 0.0980 - val_accuracy: 0.9702
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1072 - accuracy: 0.9672 - val_loss: 0.0883 - val_accuracy: 0.9743
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0887 - accuracy: 0.9726 - val_loss: 0.0743 - val_accuracy: 0.9779
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0744 - accuracy: 0.9767 - val_loss: 0.0751 - val_accuracy: 0.9770
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0666 - accuracy: 0.9788 - val_loss: 0.0700 - val_accuracy: 0.9770
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0575 - accuracy: 0.9814 - val_loss: 0.0715 - val_accuracy: 0.9783
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0535 - accuracy: 0.9821 - val_loss: 0.0702 - val_accuracy: 0.9805
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0473 - accuracy: 0.9843 - val_loss: 0.0715 - val_accuracy: 0.9783
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0450 - accuracy: 0.9850 - val_loss: 0.0777 - val_accuracy: 0.9788

# %% [markdown]
# 2. Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model
# on that single image

# %%
import numpy as np

# Select a random image from the test data
index = np.random.randint(0, len(x_val))
sample_image = x_val[index]
true_label = y_val[index]

# Reshape the image to match the model's input shape
sample_image = np.expand_dims(sample_image, axis=0)

# Perform inference
predictions = model.predict(sample_image)

# Get the predicted label (class) for the image
predicted_label = np.argmax(predictions)

# Define a list of class labels (digits 0-9)
class_labels = [str(i) for i in range(10)]

# Plot the selected image
plt.figure(figsize=(4, 4))
plt.imshow(sample_image[0], cmap='gray')
plt.title(f"True Label: {class_labels[true_label]}\nPredicted Label: {class_labels[predicted_label]}")
plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 131ms/step

# %% [markdown]
# 3. We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the
# activation to tanh or sigmoid and see what happens.

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))
# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.0691, Test accuracy: 0.9813
# 1 hidden layer with sigmoid - Test loss: 0.0602, Test accuracy: 0.9819
# 2 hidden layers with tanh - Test loss: 0.0821, Test accuracy: 0.9787
# 2 hidden layers with sigmoid - Test loss: 0.0688, Test accuracy: 0.9816

# %% [markdown]
# 4. Run the same code without scaling the images and check the performance?

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))
# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with tanh', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))
# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.1828, Test accuracy: 0.9435
# 1 hidden layer with sigmoid - Test loss: 0.1488, Test accuracy: 0.9546
# 2 hidden layers with tanh - Test loss: 0.1490, Test accuracy: 0.9552
# 2 hidden layers with sigmoid - Test loss: 0.1063, Test accuracy: 0.9652
